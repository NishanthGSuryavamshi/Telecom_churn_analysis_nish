# %%
import pandas as pd
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from imblearn.combine import SMOTEENN

# %%
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement imbearn (from versions: none)
# ERROR: No matching distribution found for imbearn

# %%
df= pd.read_csv('tele_churn.csv')

# %%
df
# Out:
#       Unnamed: 0  SeniorCitizen  MonthlyCharges  TotalCharges  Churn  \
# 0              0              0           29.85         29.85      0
# 1              1              0           56.95       1889.50      0
# 2              2              0           53.85        108.15      1
# 3              3              0           42.30       1840.75      0
# 4              4              0           70.70        151.65      1
# ...          ...            ...             ...           ...    ...
# 7027        7038              0           84.80       1990.50      0
# 7028        7039              0          103.20       7362.90      0
# 7029        7040              0           29.60        346.45      0
# 7030        7041              1           74.40        306.60      1
# 7031        7042              0          105.65       6844.50      0
#
#       gender_Female  gender_Male  Partner_No  Partner_Yes  Dependents_No  ...  \
# ...

# %%
x=df.drop('Unnamed: 0',axis=1)

# %%
x
# Out:
#       SeniorCitizen  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0                 0           29.85         29.85      0              1
# 1                 0           56.95       1889.50      0              0
# 2                 0           53.85        108.15      1              0
# 3                 0           42.30       1840.75      0              0
# 4                 0           70.70        151.65      1              1
# ...             ...             ...           ...    ...            ...
# 7027              0           84.80       1990.50      0              0
# 7028              0          103.20       7362.90      0              1
# 7029              0           29.60        346.45      0              1
# 7030              1           74.40        306.60      1              0
# 7031              0          105.65       6844.50      0              0
#
#       gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  \
# ...

# %%
x=x.drop('Churn',axis=1)

# %%
x
# Out:
#       SeniorCitizen  MonthlyCharges  TotalCharges  gender_Female  gender_Male  \
# 0                 0           29.85         29.85              1            0
# 1                 0           56.95       1889.50              0            1
# 2                 0           53.85        108.15              0            1
# 3                 0           42.30       1840.75              0            1
# 4                 0           70.70        151.65              1            0
# ...             ...             ...           ...            ...          ...
# 7027              0           84.80       1990.50              0            1
# 7028              0          103.20       7362.90              1            0
# 7029              0           29.60        346.45              1            0
# 7030              1           74.40        306.60              0            1
# 7031              0          105.65       6844.50              0            1
#
# ...

# %%
y=df['Churn']

# %%
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7027    0
# 7028    0
# 7029    0
# 7030    1
# 7031    0
# Name: Churn, Length: 7032, dtype: int64

# %%
x
# Out:
#       SeniorCitizen  MonthlyCharges  TotalCharges  gender_Female  gender_Male  \
# 0                 0           29.85         29.85              1            0
# 1                 0           56.95       1889.50              0            1
# 2                 0           53.85        108.15              0            1
# 3                 0           42.30       1840.75              0            1
# 4                 0           70.70        151.65              1            0
# ...             ...             ...           ...            ...          ...
# 7027              0           84.80       1990.50              0            1
# 7028              0          103.20       7362.90              1            0
# 7029              0           29.60        346.45              1            0
# 7030              1           74.40        306.60              0            1
# 7031              0          105.65       6844.50              0            1
#
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7027    0
# 7028    0
# 7029    0
# 7030    1
# 7031    0
# Name: Churn, Length: 7032, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#       SeniorCitizen  MonthlyCharges  TotalCharges  gender_Female  gender_Male  \
# 6008              0           56.15        291.45              0            1
# 3826              0           74.75        827.05              0            1
# 3682              0           98.05       3990.60              1            0
# 3714              0           54.55       2455.05              1            0
# 2128              1           70.55         70.55              1            0
# ...             ...             ...           ...            ...          ...
# 4695              1           78.85       1772.25              0            1
# 6769              0           44.80        559.20              0            1
# 3499              0           24.95        190.25              0            1
# 1517              0           68.85       1970.50              1            0
# 2258              0           98.15        567.45              1            0
#
# ...

# %%
model_dt=DecisionTreeClassifier(criterion='gini',random_state=100,max_depth=8,min_samples_leaf=8)

# %%
model_dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=8, min_samples_leaf=8, random_state=100)

# %%
y_pred=model_dt.predict(x_test)

# %%
model_dt.score(x_test,y_test)
# Out:
# 0.7583511016346838

# %%
print(classification_report(y_test,y_pred,labels=(0,1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.84      1003
#            1       0.60      0.47      0.53       404
#
#     accuracy                           0.76      1407
#    macro avg       0.70      0.67      0.68      1407
# weighted avg       0.75      0.76      0.75      1407

# %%
#imbalanced data so accuracy is cursed
sm=SMOTEENN(sampling_strategy=.5)
x_r,y_r=sm.fit_sample(x,y)

# %%
x_r
# Out:
#       SeniorCitizen  MonthlyCharges  TotalCharges  gender_Female  gender_Male  \
# 0                 0       56.950000   1889.500000              0            1
# 1                 0       42.300000   1840.750000              0            1
# 2                 0       56.150000   3487.950000              0            1
# 3                 0      105.500000   2686.050000              0            1
# 4                 0      106.700000   7382.250000              0            1
# ...             ...             ...           ...            ...          ...
# 3764              0       80.991366   1629.601524              0            0
# 3765              0       74.887483    541.320224              0            0
# 3766              0       76.692392     76.692392              1            0
# 3767              0       80.532784    412.835050              1            0
# 3768              0      104.494295   6276.219461              0            0
#
# ...

# %%
x_r_train,x_r_test,y_r_train,y_r_test=train_test_split(x_r,y_r,test_size=.2)

# %%
model_dt_r=DecisionTreeClassifier(criterion='gini',random_state=100,max_depth=6,min_samples_leaf=8)
model_dt_r.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=6, min_samples_leaf=8, random_state=100)

# %%
y_r_pred=model_dt_r.predict(x_r_test)

# %%
model_dt_r.score(x_r_test,y_r_test)
# Out:
# 0.9456233421750663

# %%
print(classification_report(y_r_test,y_r_pred,labels=(0,1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       576
#            1       0.94      0.82      0.88       178
#
#     accuracy                           0.95       754
#    macro avg       0.94      0.90      0.92       754
# weighted avg       0.95      0.95      0.94       754

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rf=RandomForestClassifier(n_estimators=100, criterion='gini', random_state = 100,max_depth=6, min_samples_leaf=8)

# %%
model_rf.fit(x_r,y_r)
# Out:
# RandomForestClassifier(max_depth=6, min_samples_leaf=8, random_state=100)

# %%
model_rf_1=model_rf.fit(x_r_train,y_r_train)

# %%
model_rf_1
# Out:
# RandomForestClassifier(max_depth=6, min_samples_leaf=8, random_state=100)

# %%
model_rf_1_pred=model_rf_1.predict(x_r_test)

# %%
model_rf_1.score(x_r_test,y_r_test)
# Out:
# 0.9562334217506632

# %%
print(classification_report(y_r_test,y_r_pred,labels=(0,1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       576
#            1       0.94      0.82      0.88       178
#
#     accuracy                           0.95       754
#    macro avg       0.94      0.90      0.92       754
# weighted avg       0.95      0.95      0.94       754

# %%
import pickle

# %%
filename = 'finalized_model.sav'
pickle.dump(model_rf_1, open(filename, 'wb'))

# %%
load_mod=pickle.load(open(filename,'rb'))

# %%
load_mod.score(x_r_test,y_r_test)
# Out:
# 0.9562334217506632
